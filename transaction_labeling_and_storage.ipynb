# %% [markdown]
# This program takes temporary credit card transaction data, cleans it up, and adds it to a CSV file containing a history of all credit card transactions.
#
# Details:
# - Credit card transaction data is supported for Capital One.
# - The data gets categorized based on mappings done by Lukas. If the mapping for a business doesn't exist, it uses ChatGPT to categorize it.
#
# To-do:
# 1. ~~Leverage ChatGPT to categorize businesses that don't have a category and store result in categorized businesses~~
# 2. Craft a summary of expenses for the past 3 months?
# 3. Create unit tests to ensure program works as expected

# %%
from datetime import datetime
import os
from openai import OpenAI
import pandas as pd
import send2trash

# Constants
BUSINESS_OR_PERSON = 'business_or_person'
BUSINESS_OR_PERSON_ORIGINAL= 'business_or_person_original'
CARD_NUMBER = 'card_number'
CATEGORY = 'category'
CATEGORY_ORIGINAL = 'category_original'
CREDIT = 'credit'
DATE = 'date'
DEBIT = 'debit'
SEQUENCE = 'sequence'

DATA_DIRECTORY_PATH = 'data/'
TEMP_DIRECTORY_PATH = DATA_DIRECTORY_PATH + 'temp/'
IMPORTED_TRANSACTIONS_DIRECTORY_PATH = DATA_DIRECTORY_PATH + 'imported_transactions/'
TRANSACTIONS_HISTORY_FILE_PATH = DATA_DIRECTORY_PATH + 'transactions_history.csv'

CATEGORIES_DF = pd.read_csv(DATA_DIRECTORY_PATH + 'categories.csv')
column_to_drop = 'Unnamed: 1'
if column_to_drop in CATEGORIES_DF.columns:
    CATEGORIES_DF.drop(column_to_drop, axis=1, inplace=True)
print("Valid Categories:")
pd.set_option('display.max_rows', None)
print(CATEGORIES_DF)
pd.set_option('display.max_rows', 60)

TEMP_FILES = [f for f in os.listdir(TEMP_DIRECTORY_PATH) if os.path.isfile(os.path.join(TEMP_DIRECTORY_PATH, f))]
CSV_FILES = [s for s in TEMP_FILES if s.lower().endswith('csv')] 

# Functions

def get_capital_one_dataframe(csv):
    """Reads a Capital One CSV file and preprocesses it."""
    df = pd.read_csv(csv, encoding='latin-1')
    
    df = df.rename(columns={
        'Transaction Date': DATE, 
        'Card No.': CARD_NUMBER, 
        'Description': BUSINESS_OR_PERSON_ORIGINAL, 
        'Category': CATEGORY, 
        'Debit': DEBIT, 
        'Credit': CREDIT })
    
    # Check dataframe is in expected format.
    expected_columns = [DATE, CARD_NUMBER, BUSINESS_OR_PERSON_ORIGINAL, CATEGORY, DEBIT, CREDIT]
    if not all(col in df.columns for col in expected_columns):
        raise ValueError("DataFrame is missing one or more expected columns.")
    
    df[BUSINESS_OR_PERSON_ORIGINAL] = df[BUSINESS_OR_PERSON_ORIGINAL].str.lower()
    df[BUSINESS_OR_PERSON] = df[BUSINESS_OR_PERSON_ORIGINAL].str.replace('[\d#]+', '', regex=True)

    df[CATEGORY] = df[CATEGORY].str.lower()

    # Merge transactions with categorized_businesses_df to get correct categories
    categorized_businesses_df = pd.read_csv(DATA_DIRECTORY_PATH + 'categorized_businesses.csv')
    df = pd.merge(df, categorized_businesses_df, on=BUSINESS_OR_PERSON, how='left')

    df = df.rename(columns={
        'category_x': CATEGORY_ORIGINAL, 
        'category_y': CATEGORY})
    
    # Merge with categories to get the correct category names
    df = pd.merge(df, CATEGORIES_DF, on=CATEGORY, how='left')

    df = df.dropna(subset=[DEBIT])
    df.drop('Posted Date', axis=1, inplace=True)

    # Create a unique identifier for each transaction.
    df[SEQUENCE] = df.groupby([DATE, CARD_NUMBER, BUSINESS_OR_PERSON_ORIGINAL, DEBIT]).cumcount() + 1

    return df

def get_valid_category():
    while True:
        user_input = input("Enter a category: ").strip().lower()

        if user_input in CATEGORIES_DF[CATEGORY].str.lower().values:
            return user_input
        else:
            print("Invalid category. Please try again.")

def get_category_from_api(row):
    category = row[CATEGORY]

    if pd.isna(category):
        business = row[BUSINESS_OR_PERSON]
        business_original = row[BUSINESS_OR_PERSON_ORIGINAL]

        client = OpenAI()

        completion = client.chat.completions.create(
            model="gpt-3.5-turbo",
            messages=[
                {"role": "system", "content": "You are an experienced business analyst who speaks every language and can find businesses using descriptions from credit card transactions. Use provided business descriptions to categorize transactions based on the name a business provides to the transaction. If you can't decide between one or more, pick the category that is more specific. If no category fits, return 'no category'. This list contains the category along with a description in parenthesis: groceries (), home (Any home improvements or furniture), learning (Businesses that sells books or provide teaching services like language tutoring), dining (restaurants, bakeries, cafes, kiosks, etc.), entertainment (All forms of entertainment including concerts, movies, sports games, etc.), exercise (gym, swimming, sports stores, bike stores), car/bike/metro (Public transportation used within a city, scooter/bike rental services, ride-sharing services like Uber/Lyft, or anything related to car services like gas, car parts, or car repairs), travel (Any travel from one city to another including trains, flights, and hotels/airbnbs), utilities (mobile phone related coses, internet, electricity, water, etc.), health care (hospitals, pharmacies, etc.), insurance (), pet care (pet stores), donation (Non-profits), merchandise (Purchases like clothes, online purchases, etc.)."},
                {"role": "user", "content": f"What is the category for '{business_original}'? Please only respond with the category."}
            ],
            temperature=0.1 
        )

        updated_category = completion.choices[0].message.content

        if CATEGORIES_DF[CATEGORY].str.contains(updated_category).any():
            print(f"Chat GPT labeled {business} as {updated_category}")
        else:
            print()
            print(f"CHATGPT could not categorize the business correctly: {business_original}")
            print(f"Original category: {row[CATEGORY_ORIGINAL]}")
            print(f"Amount: ${row[DEBIT]}")
            updated_category = get_valid_category()
            
        # Add new category to business:category mappings.
        new_record = pd.DataFrame({BUSINESS_OR_PERSON: [business], CATEGORY: [updated_category]})

        categorized_businesses_df = pd.read_csv(DATA_DIRECTORY_PATH + 'categorized_businesses.csv')
        categorized_businesses_df = pd.concat([categorized_businesses_df, new_record], ignore_index=True)
        categorized_businesses_df = categorized_businesses_df.drop_duplicates()
        categorized_businesses_df.to_csv(DATA_DIRECTORY_PATH + 'categorized_businesses.csv', index=False)

        return updated_category
    else:
        return category

def check_for_approved_categories(df):
    """Checks if DataFrame contains approved categories."""
    categories_set = set(CATEGORIES_DF[CATEGORY])
    unique_categories_df = set(df[CATEGORY])
    categories_not_in_csv = unique_categories_df - categories_set

    if categories_not_in_csv:
        print("The DataFrame contains categories not existing in the 'categories.csv' file:")
        print(categories_not_in_csv)
    else:
        print("Dataframe contains no unapproved categories. Import successful!")

def get_transactions_df():
    """Processes all CSV files in the temp directory."""

    # Add all transactions to one dataframe
    transactions_df = pd.DataFrame()

    for file in CSV_FILES:
        df = get_capital_one_dataframe(TEMP_DIRECTORY_PATH + file)
        transactions_df = pd.concat([transactions_df, df])
    
    return transactions_df

def send_csv_files_to_trash():
    """Moves CSV files in temp directory to trash."""
    for file in CSV_FILES:
        file_path = TEMP_DIRECTORY_PATH + file

        # Check if the file exists before attempting to delete
        if os.path.exists(file_path):
            # Move the file to the trash
            send2trash.send2trash(file_path)
            print(f"File '{file_path}' moved to trash successfully.")
        else:
            print(f"File '{file_path}' does not exist.")

# Main

def main():
    transactions_df = get_transactions_df()

    if transactions_df.empty:
        return
    else:
        # Get today's date
        today_date = datetime.today().strftime('%Y-%m-%d')

        # Create filename with today's date
        filename = f"transactions_{today_date}.csv"
        transactions_df.to_csv(IMPORTED_TRANSACTIONS_DIRECTORY_PATH + filename, index=False)

        # Update missing categories using llm
        transactions_df['category'] = transactions_df.apply(get_category_from_api, axis=1)

        # Add rows from transaction history to current transactions data frame.
        if os.path.exists(TRANSACTIONS_HISTORY_FILE_PATH):
            transaction_history_df = pd.read_csv(TRANSACTIONS_HISTORY_FILE_PATH)
            transactions_df = pd.concat([transactions_df, transaction_history_df], ignore_index=True)

        # Remove transactions that have already been added.
        transactions_df = transactions_df.drop_duplicates(subset=[DATE, BUSINESS_OR_PERSON_ORIGINAL, DEBIT, SEQUENCE])

        # Sort by date.
        transactions_df = transactions_df.sort_values(by=[DATE, CATEGORY, BUSINESS_OR_PERSON], ascending=[False, True, True])

        # Save for long-term storage.
        transactions_df.to_csv(TRANSACTIONS_HISTORY_FILE_PATH, index=False)

        check_for_approved_categories(transactions_df)
        send_csv_files_to_trash()

main()
# Out:
# Valid Categories:
#           category
# 0   car/bike/metro
# 1        groceries
# 2             home
# 3         learning
# 4           dining
# 5      merchandise
# 6           travel
# 7    entertainment
# 8         exercise
# 9        utilities
# 10     health care
# 11       insurance
# 12        pet care
# 13        donation
# Transactions getting imported:
#            date  card_number business_or_person_original  \
# 0    2023-12-16         3363            nextbike by tier
# 1    2023-12-11         3363       kindle svcs*b38mh3283
# 3    2023-12-04         3363              apple.com/bill
# 5    2023-11-29         3363            nextbike by tier
# 6    2023-11-24         3363            nextbike by tier
# 8    2023-11-21         3363            nextbike by tier
# 9    2023-11-19         3363            nextbike by tier
# 10   2023-11-16         3363            nextbike by tier
# 11   2023-11-15         3363            db vertrieb gmbh
# 12   2023-11-11         3363            nextbike by tier
# 13   2023-11-09         3363            nextbike by tier
# 14   2023-11-09         3363                apple.com/us
# 15   2023-11-07         3363            db vertrieb gmbh
# 16   2023-11-06         3363            nextbike by tier
# 17   2023-11-05         3363              apple.com/bill
# 18   2023-11-04         3363            nextbike by tier
# 19   2023-11-04         3363              apple.com/bill
# 21   2023-10-31         3363            nextbike by tier
# 22   2023-10-29         3363            nextbike by tier
# 23   2023-10-27         3363            nextbike by tier
# 24   2023-10-24         3363            tier mobility se
# 25   2023-10-21         3363            tier mobility se
# 26   2023-10-18         3363                    yesss.at
# 27   2023-10-18         3363      amzn mktp de*h87hp6uo4
# 28   2023-10-19         3363            tier mobility se
# 30   2023-10-03         3363      wr.staedt.vers. 404581
# 31   2023-10-04         3363              ventra account
# 32   2023-10-04         3363            tier mobility se
# 33   2023-10-04         3363              apple.com/bill
# 34   2023-10-02         3363            tier mobility se
# 35   2023-09-29         3363            tier mobility se
# 36   2023-09-20         3363            paypal *momox se
# 38   2023-09-06         3363                      openai
# 39   2023-09-06         3363                      openai
# 40   2023-09-04         3363              apple.com/bill
# 43   2023-08-10         3363            tier mobility se
# 44   2023-08-09         3363                 bike24 gmbh
# 45   2023-08-04         3363              apple.com/bill
# 46   2023-08-05         3363            tier mobility se
# 48   2023-08-04         3363       kindle svcs*ta16q8ol0
# 50   2023-08-02         3363            tier mobility se
# 51   2023-07-31         3363            tier mobility se
# 53   2023-07-20         3363       kindle svcs*6979w5n53
# 54   2023-07-18         3363                    yesss.at
# 55   2023-07-18         3363         tmobile*prepaid web
# 56   2023-07-12         3363      amzn mktp de*1k2el97f5
# 57   2023-07-05         3363              apple.com/bill
# 58   2023-07-04         3363      eb *american comedy ni
# 59   2023-07-02         3363       kindle svcs*ac8gk3fl3
# 61   2023-06-20         3363            tier mobility se
# 63   2023-06-16         3363      amzn mktp de*069km88r5
# 65   2023-06-05         3363      amzn mktp de*fo6q88vy5
# 66   2023-06-04         3363              apple.com/bill
# 67   2023-06-02         3363            tier mobility se
# 68   2023-05-29         3363            tier mobility se
# 69   2023-05-28         3363      amzn mktp de*c441v1jt5
# 70   2023-05-27         3363            tier mobility se
# 71   2023-05-27         3363      ikea austria onlinesho
# 72   2023-05-25         3363            tier mobility se
# 73   2023-05-23         3363            tier mobility se
# 74   2023-05-19         3363                    yesss.at
# 75   2023-05-21         3363            tier mobility se
# 76   2023-05-19         3363        hervis fil.308102500
# 77   2023-05-19         3363            nextbikeatvienna
# 78   2023-05-18         3363      schönbrunner tiergarte
# 79   2023-05-16         3363      khm-museumsverband onl
# 81   2023-05-14         3363           wiener linien 229
# 82   2023-05-14         3363         oebb ticket automat
# 83   2023-05-13         3363         chatterbug learning
# 84   2023-05-12         3363      obi bau- und heimwerke
# 85   2023-05-11         3363            ikea europaplatz
# 86   2023-05-12         3363      amzn mktp de*ly8pk6xc5
# 87   2023-05-08         3363                vivobarefoot
# 88   2023-05-06         3363          thalia.at fil.6670
# 89   2023-05-06         3363         oebb ticket automat
# 90   2023-05-04         3363              apple.com/bill
# 92   2023-04-29         3363            ikea europaplatz
# 93   2023-04-26         3363          thalia.at fil.6670
# 94   2023-04-24         3363       kindle svcs*hf8xd0ll2
# 95   2023-04-24         3363       kindle svcs*hf1ce7ta1
# 97   2023-04-23         3363              apple.com/bill
# 98   2023-04-22         3363      amzn mktp de*1p0b16om5
# 99   2023-04-22         3363        georgian airways ltd
# 100  2023-04-22         3363        canyon bicycles gmbh
# 101  2023-04-19         3363      86e0f263-8d94-4746-901
# 102  2023-04-15         3363                   ankerbrot
# 103  2023-04-15         3363              stadthallenbad
# 104  2023-04-15         3363          wiener linien 2307
# 105  2023-04-15         3363                 back market
# 106  2023-04-13         3363           wiener linien 171
# 107  2023-04-13         3363           wiener linien 164
# 108  2023-04-13         3363              tk maxx vienna
# 109  2023-04-13         3363      amzn mktp de*uq3kw83j5
# 110  2023-04-13         3363         chatterbug learning
# 111  2023-04-13         3363       halfprice mariahilfer
# 112  2023-04-12         3363      stadt wien ma 44 jörge
# 113  2023-04-09         3363           wiener linien 228
# 114  2023-04-08         3363          multi trade handel
# 115  2023-04-07         3363          wiener linien 2300
# 117  2023-04-05         3363      stadt wien ma 44 jörge
# 118  2023-04-04         3363              apple.com/bill
# 120  2023-04-02         3363      stadt wien ma 44 jörge
# 121  2023-03-31         3363      stadt wien ma 44 jörge
# 122  2023-03-29         3363      obi bau- und heimwerke
# 123  2023-03-29         3363                   7127 wien
# 124  2023-03-28         3363      stadt wien ma 44 jörge
# 125  2023-03-25         3363      amzn mktp de*j94o64cl5
# 126  2023-03-24         3363            uzr*bike 24 gmbh
# 127  2023-03-23         3363      stadt wien ma 44 jörge
# 128  2023-03-21         3363              stadthallenbad
# 129  2023-03-21         3363      amzn mktp de*2g1dg78y5
# 130  2023-03-20         3363              loja portuguez
# 131  2023-03-20         3363      amzn mktp de*1x7cq6vb4
# 132  2023-03-20         3363             spar dankt 4854
# 134  2023-03-17         3363      blumen am kutschkermar
# 135  2023-03-17         3363           italki hk limited
# 137  2023-03-14         3363              stadthallenbad
# 138  2023-03-13         3363         chatterbug learning
# 139  2023-03-05         3363      amzn mktp de*1r6d71l14
# 140  2023-03-06         3363      amzn mktp de*1r4lj7zh4
# 141  2023-03-05         3363        federal express gmbh
# 142  2023-03-04         3363              apple.com/bill
# 143  2023-03-04         3363              apple.com/bill
# 145  2023-03-03         3363               der bergspezl
# 146  2023-03-03         3363               der bergspezl
# 147  2023-03-02         3363         paypal *enjoyyourca
# 148  2023-03-03         3363               steffl outlet
# 149  2023-03-03         3363                steffl sport
# 150  2023-03-02         3363       halfprice mariahilfer
# 152  2023-02-28         3363      stadt wien ma 44 jörge
# 153  2023-02-24         3363      stadt wien ma 44 jörge
# 154  2023-02-22         3363           wiener linien 229
# 155  2023-02-21         3363      stadt wien ma 44 jörge
# 156  2023-02-20         3363            ikea europaplatz
# 158  2023-02-17         3363      stadt wien ma 44 jörge
# 159  2023-02-15         3363                dm-fil. 0937
# 160  2023-02-14         3363      stadt wien ma 44 jörge
# 161  2023-02-14         3363          wiener linien 2290
# 162  2023-02-14         3363              internetstores
# 163  2023-02-13         3363         chatterbug learning
# 164  2023-02-13         3363           italki hk limited
# 165  2023-02-12         3363      stadt wien ma 44 jörge
# 166  2023-02-05         3363      stadt wien ma 44 jörge
# 167  2023-02-04         3363              apple.com/bill
# 168  2023-02-02         3363      stadt wien ma 44 jörge
# 170  2023-02-01         3363              libro fil.1818
# 171  2023-02-01         3363                espressorado
# 172  2023-02-01         3363               mountainbiker
# 173  2023-01-31         3363      stadt wien ma 44 jörge
# 174  2023-01-31         3363                   amazon.de
# 175  2023-01-30         3363    ryanair0000000000cfrk5g0
# 176  2023-01-30         3363          etsy.com - ikechop
# 177  2023-01-30         3363      westwingnow.de 8965143
# 178  2023-01-29         3363      stadt wien ma 44 jörge
# 179  2023-01-27         3363      amzn mktp de*1o76f5at4
# 180  2023-01-26         3363      stadt wien ma 44 jörge
# 181  2023-01-25         3363               sp ass savers
# 182  2023-01-24         3363      stadt wien ma 44 jörge
# 183  2023-01-23         3363         mountainbiker dankt
# 184  2023-01-21         3363      workout freizeitanlage
# 185  2023-01-22         3363      piano teachers connect
# 186  2023-01-22         3363      stadt wien ma 44 jörge
# 187  2023-01-19         3363              stadthallenbad
# 188  2023-01-19         3363          wiener linien 2283
# 189  2023-01-18         3363                   amazon.de
# 190  2023-01-18         3363         tmobile*prepaid web
# 191  2023-01-18         3363      amzn mktp de*1a1ug0xf4
# 192  2023-01-18         3363      obi bau- und heimwerke
# 193  2023-01-17         3363            artistworks, llc
# 195  2023-01-14         3363      amzn mktp de*1a6nz8o24
# 196  2023-01-13         3363                   amazon.de
# 197  2023-01-13         3363         chatterbug learning
# 198  2023-01-12         3363        canyon bicycles gmbh
# 199  2023-01-10         3363      stadt wien ma 44 jörge
# 200  2023-01-10         3363      amzn mktp de*1h7el4ql4
# 201  2023-01-09         3363                vienna piano
# 202  2023-01-04         3363              apple.com/bill
# 203  2023-01-03         3363              internetstores
# 205  2023-01-02         3363       manifattura valcismon
# 207  2023-01-01         3363                blumenkultur
# 0    2023-12-29         8035              cph coffee lab
# 1    2023-12-29         8035       sumup  *fisch und co.
# 2    2023-12-29         5739      boussi falafel  ep gmb
# 3    2023-12-29         5739      schanzenbaeckerei gros
# 4    2023-12-29         5739            kiosk pavillon 3
# 5    2023-12-29         5739               cafe am hafen
# 6    2023-12-28         5739       starke baecker kg fil
# 7    2023-12-28         5739              espresso house
# 9    2023-12-27         8035         gosch-sylt hannover
# 10   2023-12-27         8035       starke baecker kg fil
# 11   2023-12-27         5739         gosch-sylt hannover
# 12   2023-12-27         5739                rossmann 104
# 13   2023-12-23         5739       starke baecker kg fil
# 14   2023-12-23         5739        restaurant bandonion
# 15   2023-12-23         5739                edeka fehner
# 16   2023-12-22         5739       starke baecker kg fil
# 17   2023-12-22         5739                edeka fehner
# 18   2023-12-21         5739            spc*d. s. blumen
# 19   2023-12-21         5739       starke baecker kg fil
# 20   2023-12-20         8035           db fernverkehr ag
# 21   2023-12-20         5739      le crobag hannover hbf
# 22   2023-12-20         5739                     cafe 12
# 23   2023-12-20         5739      dornauers handwerkerho
# 24   2023-12-19         8035                dm-fil. 0602
# 25   2023-12-19         8035              lidl dankt 593
# 26   2023-12-19         5739                 billa dankt
# 27   2023-12-19         5739                   post 1172
# 28   2023-12-19         5739                   post 1172
# 29   2023-12-18         5739         interspar fil. 8730
# 30   2023-12-16         5739      mueller mha handelsgmb
# 31   2023-12-16         5739                 joseph brot
# 32   2023-12-16         5739                 billa dankt
# 34   2023-12-15         5739                 billa dankt
# 35   2023-12-15         5739              libro fil.1784
# 36   2023-12-14         5739                 billa dankt
# 37   2023-12-14         5739      der mann - backwaren 9
# 38   2023-12-11         5739              lidl dankt 496
# 39   2023-12-11         5739                 billa dankt
# 41   2023-12-08         8035            aycan supermarkt
# 42   2023-12-10         5739                fenster cafe
# 43   2023-12-09         5739              coffee pirates
# 44   2023-12-10         5739      ströck 3087 löwengasse
# 45   2023-12-10         5739        neu*prater wien gmbh
# 46   2023-12-09         5739                 joseph brot
# 47   2023-12-09         5739      offerl - schottengasse
# 48   2023-12-09         5739              spar fil. 4802
# 49   2023-12-09         5739       hotel imperial vienna
# 50   2023-12-07         5739      lpd wien - verkehrsamt
# 51   2023-12-07         5739      ströck 3045 kardinal-n
# 52   2023-12-07         5739         interspar fil. 8300
# 53   2023-12-06         8035                  bipa dankt
# 54   2023-12-06         8035                dm-fil. 0002
# 55   2023-12-06         8035                 billa dankt
# 56   2023-12-06         5739                 billa dankt
# 57   2023-12-06         5739           wiener linien 229
# 58   2023-12-06         5739         oebb ticket automat
# 59   2023-12-06         5739         oebb ticket automat
# 60   2023-12-05         5739       me group austria gmbh
# 61   2023-12-05         8035              lidl dankt 593
# 62   2023-12-05         5739        hernals. kebap pizza
# 63   2023-12-05         5739         interspar fil. 8730
# 64   2023-12-05         5739                 hofer dankt
# 65   2023-12-04         5739         oeamtc reisen  1002
# 66   2023-12-04         5739              libro fil.1784
# 67   2023-12-04         5739            offerl wollzeile
# 69   2023-12-03         5739       ströck 3088 wien nord
# 70   2023-12-03         5739           wiener linien 789
# 71   2023-12-03         5739      lieferando.at lieferse
# 72   2023-12-03         5739                   ankerbrot
# 73   2023-12-02         5739      der mann - backwaren 9
# 74   2023-12-02         5739           wiener linien 148
# 75   2023-12-01         8035                 billa dankt
# 76   2023-12-01         5739                  motto brot
# 77   2023-12-01         5739             haus des meeres
# 78   2023-12-01         5739                 cafe sharky
# 79   2023-12-01         5739           wiener linien 171
# 81   2023-11-27         5739              lidl dankt 496
# 82   2023-11-27         5739         interspar fil. 8200
# 83   2023-11-26         5739         steinmetz gastro gm
# 84   2023-11-26         5739            bäckerei martini
# 85   2023-11-25         8035                dm-fil. 0043
# 86   2023-11-25         5739                 hofer dankt
# 87   2023-11-24         5739        hernals. kebap pizza
# 89   2023-11-23         5739                 billa dankt
# 90   2023-11-21         5739                       matco
# 91   2023-11-20         5739      ströck 3046 schwedenpl
# 92   2023-11-20         5739                 billa dankt
# 93   2023-11-20         5739                 billa dankt
# 94   2023-11-18         8035                 billa dankt
# 95   2023-11-18         5739               libro fil.695
# 96   2023-11-18         5739                 hofer dankt
# 97   2023-11-18         5739              joe&joe vienna
# 98   2023-11-18         5739              joe&joe vienna
# 99   2023-11-18         5739        sumup  *caffecouture
# 100  2023-11-18         5739                street grill
# 101  2023-11-17         5739                 billa dankt
# 102  2023-11-17         5739      sumup  *zm gastro gmbh
# 103  2023-11-16         5739                speisekammer
# 105  2023-11-14         8035                 billa dankt
# 106  2023-11-13         5739                 billa dankt
# 107  2023-11-11         5739                 hofer dankt
# 108  2023-11-11         5739      obi bau- und heimwerke
# 109  2023-11-09         5739      der mann - backwaren 9
# 110  2023-11-09         5739         interspar fil. 8200
# 111  2023-11-09         5739      sumup  *balthasar kaff
# 112  2023-11-08         5739                 billa dankt
# 113  2023-11-07         5739                 joseph brot
# 114  2023-11-07         5739              coffee pirates
# 115  2023-11-06         5739                 billa dankt
# 116  2023-11-05         5739                cafe wortner
# 117  2023-11-05         5739               disco volante
# 118  2023-11-05         5739        hernals. kebap pizza
# 119  2023-11-03         5739          wiener linien 2052
# 120  2023-11-04         5739                   cinnamood
# 121  2023-11-03         8035                 hofer dankt
# 122  2023-11-03         5739                 markta gmbh
# 123  2023-11-03         5739              coffee pirates
# 124  2023-11-03         5739           wiener linien 697
# 126  2023-11-01         5739           wiener linien 228
# 127  2023-10-31         5739                 billa dankt
# 128  2023-10-30         5739                 billa dankt
# 129  2023-10-30         5739        hernals. kebap pizza
# 130  2023-10-29         5739                  alser cafe
# 131  2023-10-28         8035       hotel imperial vienna
# 132  2023-10-28         5739         "nella" imbissstube
# 133  2023-10-28         5739              spar fil. 4116
# 134  2023-10-28         5739              joe&joe vienna
# 135  2023-10-26         5739                     lao lao
# 136  2023-10-26         5739           jonas reindl 1090
# 137  2023-10-27         5739         eurospar dankt 4214
# 138  2023-10-26         5739           the travelkitchen
# 140  2023-10-25         5739        hernals. kebap pizza
# 141  2023-10-25         5739         sumup  *grey kaffee
# 142  2023-10-24         8035              lidl dankt 496
# 143  2023-10-24         8035                 billa dankt
# 144  2023-10-23         5739         sumup  *grey kaffee
# 145  2023-10-21         5739                 billa dankt
# 146  2023-10-20         5739              spar fil. 4387
# 147  2023-10-18         8035              lidl dankt 496
# 148  2023-10-18         5739      sumup  *im werkzeug  g
# 149  2023-10-16         5739         lyft   1 ride 10-15
# 150  2023-10-16         5739              autogrill gmbh
# 151  2023-10-16         5739        nyx*lhgrouptastemore
# 152  2023-10-15         8035              ventra account
# 153  2023-10-15         5739              ventra account
# 154  2023-10-15         5739             zoot's cafe ord
# 155  2023-10-15         5739      frontera grill b11 ord
# 156  2023-10-15         5739        sp black fodder coff
# 157  2023-10-15         5739         sq *dayglow chicago
# 158  2023-10-15         8035      tst* dos urban cantina
# 159  2023-10-15         5739            tst* rebel & rye
# 160  2023-10-15         5739            tst* rebel & rye
# 161  2023-10-15         5739      tst* leye - do-rite do
# 162  2023-10-14         5739                   tst* xoco
# 163  2023-10-14         5739      tst* the fat shallot -
# 164  2023-10-15         5739                 uber   trip
# 166  2023-10-13         8035              ventra account
# 167  2023-10-14         5739      tst* gangnam market em
# 168  2023-10-13         5739              ventra account
# 169  2023-10-12         5739      goodwill industries 52
# 170  2023-10-13         5739               py *mca  wwmg
# 171  2023-10-10         8035              ventra account
# 172  2023-10-11         5739      tst* gangnam market em
# 173  2023-10-10         5739              ventra account
# 174  2023-10-10         5739         lyft   1 ride 10-09
# 175  2023-10-09         8035              ventra account
# 176  2023-10-09         5739           cocina del barrio
# 177  2023-10-09         5739              ventra account
# 178  2023-10-09         5739         lyft   1 ride 10-08
# 179  2023-10-08         5739          cub foods broadway
# 180  2023-10-08         5739                 uber   trip
# 181  2023-10-07         8035              ventra account
# 182  2023-10-07         8035       sq *element wood fire
# 183  2023-10-07         5739      fuzzys taco shop - min
# 184  2023-10-07         5739              ventra account
# 185  2023-10-06         5739      tst* hogsalt - small c
# 186  2023-10-07         5739       sq *element wood fire
# 188  2023-10-06         8035              ventra account
# 189  2023-10-06         5739              ventra account
# 190  2023-10-05         8035              ventra account
# 191  2023-10-06         5739      tst* gangnam market em
# 192  2023-10-05         5739              ventra account
# 193  2023-10-05         5739      tst* hogsalt - aster h
# 194  2023-10-05         8035            gps-625 michigan
# 195  2023-10-04         5739      1c united cntr concess
# 196  2023-10-05         5739        lyft   2 rides 10-04
# 197  2023-10-04         8035                   tst* fora
# 198  2023-10-04         5739              ventra account
# 199  2023-10-04         5739      bistrot brussels airpo
# 200  2023-10-03         5739                  bipa dankt
# 201  2023-10-03         5739        hernals. kebap pizza
# 202  2023-10-03         5739         interspar fil. 8730
# 203  2023-10-02         5739      mueller mha handelsgmb
# 204  2023-10-02         5739              spar fil. 4656
# 205  2023-10-02         5739                 billa dankt
# 206  2023-10-02         5739       halfprice mariahilfer
# 207  2023-10-01         5739           db fernverkehr ag
# 208  2023-09-30         8035                echt günstig
# 209  2023-09-30         5739          cafe hurricane e k
# 210  2023-09-29         5739           peter pane kassel
# 211  2023-09-29         5739          elefant am nil gbr
# 212  2023-09-29         5739             höflinger 10136
# 213  2023-09-28         5739                 billa dankt
# 214  2023-09-28         5739                 billa dankt
# 215  2023-09-28         5739          wiener linien 2375
# 216  2023-09-27         5739              spar fil. 4851
# 217  2023-09-26         5739        hernals. kebap pizza
# 218  2023-09-26         5739                 billa dankt
# 219  2023-09-23         5739                 billa dankt
# 220  2023-09-23         5739           wiener linien 752
# 221  2023-09-23         5739                 som kitchen
# 222  2023-09-22         8035                 billa dankt
# 223  2023-09-22         5739                 billa dankt
# 224  2023-09-21         5739         eurospar dankt 4214
# 225  2023-09-20         5739         verlag d. oegb gmbh
# 226  2023-09-19         5739          wiener linien 2238
# 227  2023-09-20         5739           jonas reindl 1090
# 228  2023-09-19         5739            ikea europaplatz
# 231  2023-09-19         5739      dietmar horvath backwa
# 232  2023-09-19         5739              lidl dankt 496
# 233  2023-09-18         5739      ströck 3068 meidling u
# 234  2023-09-18         5739                mcdonalds 27
# 235  2023-09-18         5739        hernals. kebap pizza
# 236  2023-09-18         5739                 billa dankt
# 237  2023-09-18         5739           wiener linien 672
# 238  2023-09-18         5739           wiener linien 665
# 239  2023-09-17         5739                  arco adige
# 240  2023-09-17         8035                 atak sultan
# 241  2023-09-16         5739      zur alten kaisermuehle
# 242  2023-09-16         5739              spar fil. 4727
# 243  2023-09-16         5739           wiener linien 873
# 244  2023-09-16         5739           wiener linien 122
# 246  2023-09-14         5739        hernals. kebap pizza
# 247  2023-09-14         5739         interspar fil. 8730
# 248  2023-09-14         5739                 billa dankt
# 249  2023-09-13         5739                 gürtel bräu
# 250  2023-09-12         5739                 billa dankt
# 251  2023-09-10         5739      oberlaa konditorei-ger
# 252  2023-09-09         5739         interspar fil. 8730
# 253  2023-09-08         8035                  bipa dankt
# 254  2023-09-08         5739                 billa dankt
# 255  2023-09-06         5739                 billa dankt
# 256  2023-09-05         5739        heurigenbuffet ernst
# 257  2023-09-05         5739                 billa dankt
# 258  2023-09-04         5739            ikea europaplatz
# 259  2023-09-04         5739            ikea europaplatz
# 260  2023-09-04         8035               libro fil.208
# 262  2023-09-03         8035             sagi restaurant
# 263  2023-09-03         5739                   modi 1080
# 264  2023-09-03         5739           wiener linien 701
# 265  2023-09-03         5739            five guys graben
# 266  2023-09-02         5739                 billa dankt
# 267  2023-09-01         5739              lidl dankt 496
# 268  2023-09-01         5739      sumup  *die markthumme
# 269  2023-08-31         5739                 joseph brot
# 270  2023-08-31         5739                 billa dankt
# 271  2023-08-30         5739          wiener linien 2156
# 272  2023-08-30         5739         oebb ticket automat
# 273  2023-08-30         5739                 markta gmbh
# 274  2023-08-28         5739                 billa dankt
# 275  2023-08-25         5739             spar dankt 4387
# 276  2023-08-26         5739            aycan supermarkt
# 277  2023-08-26         5739                 billa dankt
# 278  2023-08-24         5739         interspar fil. 8730
# 279  2023-08-24         5739                 billa dankt
# 281  2023-08-22         5739                 billa dankt
# 282  2023-08-22         5739                  motto brot
# 283  2023-08-20         5739                   foodstock
# 284  2023-08-20         5739        matsu premium teacof
# 285  2023-08-20         5739        matsu premium teacof
# 286  2023-08-20         5739             food lab s.r.o.
# 287  2023-08-20         5739             food lab s.r.o.
# 288  2023-08-20         5739                       ram s
# 289  2023-08-19         5739                 billa dankt
# 290  2023-08-18         5739                 billa dankt
# 291  2023-08-18         5739                  23 topcafe
# 292  2023-08-17         5739                 billa dankt
# 293  2023-08-14         5739                  bipa dankt
# 294  2023-08-14         5739      apotheke zum weissen k
# 295  2023-08-14         5739                 billa dankt
# 296  2023-08-12         5739              coffee pirates
# 297  2023-08-12         5739              coffee pirates
# 298  2023-08-12         5739                 markta gmbh
# 299  2023-08-12         5739               libro fil.968
# 300  2023-08-12         5739        hernals. kebap pizza
# 301  2023-08-12         5739                mel & koffie
# 302  2023-08-12         5739          wiener linien 2344
# 303  2023-08-11         5739                 billa dankt
# 304  2023-08-11         5739                 billa dankt
# 305  2023-08-10         5739         taqueria la ventana
# 306  2023-08-10         5739             spar dankt 4727
# 307  2023-08-08         5739            paypal *momox se
# 308  2023-08-08         5739        hernals. kebap pizza
# 309  2023-08-07         5739                 billa dankt
# 310  2023-08-06         5739         gelateria la romana
# 311  2023-08-05         5739                  bipa dankt
# 312  2023-08-05         5739                 billa dankt
# 313  2023-08-04         5739                 billa dankt
# 314  2023-08-04         5739                 billa dankt
# 315  2023-08-04         5739            uzr*haydnkino.at
# 317  2023-08-02         8035        interspar dankt 8200
# 318  2023-08-02         5739      leporello die buchhand
# 319  2023-07-31         8035                     tk maxx
# 320  2023-07-31         5739           wiener linien 228
# 321  2023-07-31         5739          mei shi shop & eat
# 322  2023-07-30         5739       alladean warenhandels
# 323  2023-07-30         5739        hernals. kebap pizza
# 324  2023-07-29         8035                 hofer dankt
# 325  2023-07-28         8035                 hofer dankt
# 326  2023-07-27         5739                 joseph brot
# 327  2023-07-27         5739      buchhandlung volksoper
# 328  2023-07-27         5739        hernals. kebap pizza
# 329  2023-07-27         5739            gasthaus rebhuhn
# 330  2023-07-27         5739      der mann - backwaren 9
# 331  2023-07-27         5739        buchhandlung orlando
# 332  2023-07-27         5739           jonas reindl 1090
# 333  2023-07-27         5739           jonas reindl 1090
# 334  2023-07-26         5739             spar dankt 4851
# 336  2023-07-25         5739      stadt wien ma 44 kongr
# 337  2023-07-22         5739                 charlie p's
# 338  2023-07-22         8035                 billa dankt
# 339  2023-07-22         5739         shakespeare company
# 340  2023-07-22         5739        sumup  *caffecouture
# 341  2023-07-21         5739               doenermeister
# 342  2023-07-21         5739                 billa dankt
# 344  2023-07-19         5739                  bipa dankt
# 345  2023-07-18         5739                 billa dankt
# 346  2023-07-17         5739                 billa dankt
# 348  2023-07-15         5739                mcdonalds 27
# 349  2023-07-14         8035      apotheke zum weissen k
# 350  2023-07-14         5739                 billa dankt
# 351  2023-07-14         5739                 billa dankt
# 352  2023-07-13         5739          wiener linien 2401
# 353  2023-07-13         5739         shakespeare company
# 354  2023-07-13         5739      sumup  *balthasar kaff
# 355  2023-07-13         5739         buchhandlung graben
# 356  2023-07-12         8035      sumup  *finks-lebensmi
# 357  2023-07-10         5739                 billa dankt
# 358  2023-07-10         5739        interspar dankt 8730
# 359  2023-07-08         5739                 billa dankt
# 360  2023-07-07         8035           kismet supermarkt
# 361  2023-07-06         8035      apotheke zum weissen k
# 362  2023-07-06         8035                 billa dankt
# 363  2023-07-04         8035                  bipa dankt
# 364  2023-07-04         8035                 billa dankt
# 365  2023-07-04         5739        veganista neustiftga
# 366  2023-07-02         5739          pizzeria amore mio
# 368  2023-06-30         8035                 billa dankt
# 369  2023-06-30         5739      obi bau- und heimwerke
# 370  2023-06-27         8035                 billa dankt
# 371  2023-06-27         5739        interspar dankt 8730
# 372  2023-06-26         5739            aycan supermarkt
# 374  2023-06-24         5739        offerl schottengasse
# 375  2023-06-24         5739                 billa dankt
# 376  2023-06-24         5739         sumup  *paremi gmbh
# 377  2023-06-23         5739                 billa dankt
# 378  2023-06-22         8035                 billa dankt
# 380  2023-06-21         5739      stadt wien ma 44 jörge
# 381  2023-06-21         5739                 billa dankt
# 382  2023-06-20         5739      obi bau- und heimwerke
# 383  2023-06-20         5739      gärtnerei dipl. ing zi
# 384  2023-06-19         5739                 billa dankt
# 385  2023-06-18         5739               swing kitchen
# 386  2023-06-18         5739          wiener linien 2295
# 387  2023-06-18         5739        veganista taborstras
# 388  2023-06-17         8035                 billa dankt
# 389  2023-06-16         5739                 billa dankt
# 391  2023-06-14         5739                  bipa dankt
# 392  2023-06-14         5739      apotheke zum weissen k
# 393  2023-06-14         5739      obi bau- und heimwerke
# 394  2023-06-13         5739      burger king elterleinp
# 395  2023-06-13         5739                 billa dankt
# 396  2023-06-12         5739      bartholomaeus apotheke
# 397  2023-06-11         5739          zur grunen laterne
# 398  2023-06-11         5739        cennur & volksgarten
# 399  2023-06-10         5739             superpedestrian
# 400  2023-06-10         5739             superpedestrian
# 401  2023-06-10         5739                 billa dankt
# 402  2023-06-10         5739          wiener linien 2369
# 403  2023-06-09         5739      sumup  *am garbanzo ga
# 404  2023-06-07         5739                 billa dankt
# 405  2023-06-07         5739                 billa dankt
# 406  2023-06-07         5739      obi bau- und heimwerke
# 407  2023-06-06         5739         airbnb * hm29a2qzcr
# 408  2023-06-05         5739                 billa dankt
# 410  2023-06-03         5739               stefans grill
# 411  2023-06-03         5739                   modi 1080
# 412  2023-06-03         5739        hernals. kebap pizza
# 413  2023-06-02         8035                 billa dankt
# 414  2023-06-02         5739           bushplanet clones
# 415  2023-05-31         8035                  bipa dankt
# 416  2023-05-31         5739                   kuhls bar
# 417  2023-05-31         5739                 billa dankt
# 418  2023-05-31         5739          wiener linien 2164
# 419  2023-05-30         5739          wiener linien 2393
# 420  2023-05-30         5739      obi bau- und heimwerke
# 422  2023-05-27         5739             burger boutique
# 423  2023-05-27         5739        hernals. kebap pizza
# 424  2023-05-27         5739              lidl dankt 496
# 425  2023-05-27         5739                 billa dankt
# 426  2023-05-26         5739      obi bau- und heimwerke
# 427  2023-05-26         5739                 sewa fil.14
# 428  2023-05-26         5739                 billa dankt
# 429  2023-05-26         5739           bushplanet clones
# 430  2023-05-25         5739           wiener linien 786
# 431  2023-05-25         5739          wiener linien 2393
# 432  2023-05-24         5739                 billa dankt
# 433  2023-05-23         8035                  bipa dankt
# 434  2023-05-23         8035                 billa dankt
# 435  2023-05-23         5739                 billa dankt
# 436  2023-05-22         5739         gelateria la romana
# 437  2023-05-22         5739              joe&joe vienna
# 438  2023-05-21         5739           weingut wieninger
# 439  2023-05-20         5739             l amour du pain
# 440  2023-05-20         5739                 joseph brot
# 441  2023-05-19         5739                 med and law
# 442  2023-05-19         5739                 med and law
# 443  2023-05-19         5739                 billa dankt
# 444  2023-05-17         5739      vanini1871 swiss choco
# 445  2023-05-18         5739              kaiserpavillon
# 446  2023-05-17         8035      k und k hoflieferanten
# 447  2023-05-17         5739                 joseph brot
# 448  2023-05-16         5739        interspar dankt 8200
# 449  2023-05-16         5739        hernals. kebap pizza
# 450  2023-05-16         5739        offerl schottengasse
# 451  2023-05-16         5739         cafe restaurant khm
# 452  2023-05-15         8035                 billa dankt
# 453  2023-05-15         5739                 billa dankt
# 454  2023-05-15         5739              loja portuguez
# 455  2023-05-15         5739           rasthaus rohrhaus
# 457  2023-05-15         8035                   7127 wien
# 458  2023-05-13         8035                 billa dankt
# 459  2023-05-12         5739                 billa dankt
# 460  2023-05-12         5739             spar dankt 4260
# 462  2023-05-09         5739                 billa dankt
# 463  2023-05-09         5739        interspar dankt 8730
# 464  2023-05-08         5739                dm-fil. 0002
# 465  2023-05-06         5739             spar dankt 4656
# 466  2023-05-06         5739        the lala neubaugasse
# 467  2023-05-06         5739                 bubble king
# 468  2023-05-06         5739                 joseph brot
# 469  2023-05-06         5739                  motto brot
# 470  2023-05-05         5739        veganista taborstras
# 471  2023-05-05         5739                    ramasuri
# 472  2023-05-05         5739                 billa dankt
# 473  2023-05-04         8035           billa online shop
# 474  2023-05-04         5739             spar dankt 4727
# 475  2023-05-03         8035            antikhandel emil
# 476  2023-05-03         5739        interspar dankt 8730
# 477  2023-05-02         5739         eurospar dankt 4214
# 478  2023-05-01         5739                mcdonalds 27
# 479  2023-04-30         5739                 manameierei
# 480  2023-04-29         5739              crazy khinkali
# 481  2023-04-29         5739                  motto brot
# 482  2023-04-28         5739            offerl wahringer
# 483  2023-04-27         5739                 billa dankt
# 484  2023-04-26         5739        the lala neubaugasse
# 485  2023-04-26         5739             spar dankt 4144
# 486  2023-04-24         5739                 billa dankt
# 487  2023-04-24         5739                 billa dankt
# 489  2023-04-23         5739                 joseph brot
# 490  2023-04-23         5739        hernals. kebap pizza
# 491  2023-04-22         5739             spar dankt 4825
# 492  2023-04-23         5739         mjam gmbh_sbag-00cu
# 493  2023-04-22         5739                  bipa dankt
# 494  2023-04-22         5739      meinl am graben fil. 1
# 495  2023-04-21         5739      sumup  *balthasar kaff
# 496  2023-04-21         5739                 billa dankt
# 497  2023-04-20         5739                 billa dankt
# 498  2023-04-18         5739                 billa dankt
# 499  2023-04-17         5739                 joseph brot
# 500  2023-04-17         5739                 billa dankt
# 501  2023-04-17         5739        sumup  *caffecouture
# 502  2023-04-17         5739             spar dankt 4886
# 504  2023-04-15         5739      kent fünfhaus gastrono
# 508  2023-04-13         5739             l amour du pain
# 509  2023-04-13         5739                   starbucks
# 510  2023-04-13         5739         gelateria la romana
# 511  2023-04-13         5739             spar dankt 4656
# 512  2023-04-12         8035           billa online shop
# 513  2023-04-11         5739        hernals. kebap pizza
# 514  2023-04-11         5739                 billa dankt
# 515  2023-04-09         5739                    le firin
# 516  2023-04-09         8035      oberlaa konditorei-ger
# 517  2023-04-09         5739      the ritz carlton vienn
# 518  2023-04-08         5739                 billa dankt
# 519  2023-04-07         5739        cafe goldener papage
# 520  2023-04-07         5739                 billa dankt
# 522  2023-04-06         5739                 billa dankt
# 523  2023-04-06         5739        interspar dankt 8730
# 524  2023-04-06         5739                  motto brot
# 525  2023-04-05         5739                 billa dankt
# 526  2023-04-05         5739       sumup  *am garbanzo g
# 527  2023-04-05         5739                        oben
# 528  2023-04-04         5739                 joseph brot
# 529  2023-04-04         5739       me group austria gmbh
# 530  2023-04-04         5739             spar dankt 4820
# 531  2023-04-04         5739        interspar dankt 8730
# 532  2023-04-02         5739        hernals. kebap pizza
# 533  2023-04-01         5739         gelateria la romana
# 534  2023-04-01         5739       sumup  *balthasar kaf
# 535  2023-03-29         8035           billa online shop
# 537  2023-03-27         5739                 billa dankt
# 538  2023-03-27         5739                 billa dankt
# 539  2023-03-26         5739           kaffein zeitgeist
# 540  2023-03-25         5739        restaurant wilder ma
# 541  2023-03-25         5739                 billa dankt
# 542  2023-03-24         5739      meinl am graben fil. 1
# 543  2023-03-24         5739                 billa dankt
# 544  2023-03-24         5739        offerl schottengasse
# 545  2023-03-23         5739        interspar dankt 8730
# 547  2023-03-19         5739      stadt wien ma 44 jörge
# 548  2023-03-18         5739            aycan supermarkt
# 549  2023-03-18         5739                dm-fil. 0002
# 550  2023-03-17         8035           billa online shop
# 551  2023-03-17         5739            offerl wahringer
# 552  2023-03-15         5739      bartholomaeus apotheke
# 553  2023-03-14         5739                 billa dankt
# 554  2023-03-13         5739                mcdonalds 27
# 555  2023-03-13         5739                 billa dankt
# 556  2023-03-13         5739                 billa dankt
# 557  2023-03-11         5739         rest beaver brewing
# 558  2023-03-11         5739         sumup  *grey kaffee
# 559  2023-03-10         5739              felber hernals
# 560  2023-03-09         5739              felber hernals
# 561  2023-03-08         5739             burger boutique
# 562  2023-03-09         5739        interspar dankt 8730
# 563  2023-03-07         8035           billa online shop
# 564  2023-03-07         5739         sumup  *grey kaffee
# 565  2023-03-07         5739        interspar dankt 8730
# 566  2023-03-05         5739        hernals. kebap pizza
# 567  2023-03-04         5739                 billa dankt
# 568  2023-03-03         5739        offerl mariahilfer s
# 569  2023-03-03         5739         bäckerei cafe felzl
# 570  2023-03-03         5739                 billa dankt
# 571  2023-03-02         5739                 billa dankt
# 572  2023-03-01         5739                 charlie p's
# 573  2023-03-02         5739             spar dankt 4656
# 574  2023-03-01         5739                 billa dankt
# 577  2023-02-26         8035           billa online shop
# 578  2023-02-25         5739                     lao lao
# 579  2023-02-25         5739        hernals. kebap pizza
# 580  2023-02-25         5739                mel & koffie
# 581  2023-02-25         5739                 joseph brot
# 582  2023-02-25         5739                 billa dankt
# 583  2023-02-25         5739        sumup  *caffecouture
# 584  2023-02-25         5739               funky izakaya
# 585  2023-02-24         5739                        sofi
# 586  2023-02-22         5739        leburger mariahilfer
# 587  2023-02-22         5739                 billa dankt
# 588  2023-02-22         5739         sumup  *ichiban tea
# 589  2023-02-21         5739                 billa dankt
# 590  2023-02-20         5739                 billa dankt
# 592  2023-02-18         8035         eurospar dankt 4214
# 593  2023-02-18         5739                  frau mayer
# 594  2023-02-19         5739                  frau mayer
# 595  2023-02-18         5739         eurospar dankt 4214
# 596  2023-02-18         5739                 billa dankt
# 597  2023-02-18         5739                 manameierei
# 598  2023-02-17         5739                 billa dankt
# 599  2023-02-16         5739        sumup  *crispy dream
# 600  2023-02-15         8035           billa online shop
# 601  2023-02-15         5739                 billa dankt
# 602  2023-02-15         5739                 billa dankt
# 603  2023-02-15         5739      sumup  *eissalon dolce
# 604  2023-02-15         5739        vap restaurants gmbh
# 605  2023-02-14         5739                       yamm|
# 606  2023-02-14         5739                 billa dankt
# 607  2023-02-14         5739       denn s wien mariahstr
# 608  2023-02-14         5739            offerl wahringer
# 609  2023-02-10         5739            ikea europaplatz
# 610  2023-02-11         5739                 billa dankt
# 611  2023-02-10         5739                 joseph brot
# 612  2023-02-10         5739                   zara 3113
# 613  2023-02-10         5739          sumup  *empress eu
# 614  2023-02-10         5739             jack&jones wien
# 615  2023-02-10         5739                   hm at0027
# 616  2023-02-10         5739                jonas reindl
# 618  2023-02-08         8035      cless ticket atm milan
# 619  2023-02-09         5739       obica' mozzarella bar
# 620  2023-02-09         5739       gruppo argenta s.p.a.
# 621  2023-02-09         5739         chef express s.p.a.
# 622  2023-02-09         5739         chef express s.p.a.
# 623  2023-02-08         5739      cless ticket atm milan
# 624  2023-02-08         8035            autostradale srl
# 625  2023-02-08         5739                   luini srl
# 626  2023-02-08         5739                   luini srl
# 627  2023-02-08         5739                   starbucks
# 628  2023-02-08         5739               camparino srl
# 629  2023-02-08         5739              autogrill 7175
# 630  2023-02-08         5739      la rinascente duomo 26
# 631  2023-02-08         5739                  suerte srl
# 632  2023-02-08         5739                  suerte srl
# 633  2023-02-08         5739        marchesi 1824 s.r.l.
# 634  2023-02-07         5739      stadt wien ma 44 jörge
# 635  2023-02-06         5739      der mann - backwaren 9
# 636  2023-02-05         5739      the ritz carlton vienn
# 637  2023-02-04         5739                    schwirtz
# 638  2023-02-04         8035           billa online shop
# 639  2023-02-04         5739          pizzeria angolo 22
# 640  2023-02-04         5739      uber *trip help.uber.c
# 641  2023-02-02         5739                 billa dankt
# 642  2023-02-01         8035                dm-fil. 0002
# 643  2023-02-01         8035                mel & koffie
# 644  2023-02-01         5739                mel & koffie
# 646  2023-01-29         5739      wein & co wien schotte
# 647  2023-01-29         8035                    adlerhof
# 648  2023-01-29         5739       park hyatt vienna f&b
# 649  2023-01-27         5739                    andrew's
# 650  2023-01-27         8035           billa online shop
# 651  2023-01-27         5739      sumup  *takumi ramen u
# 652  2023-01-27         5739        offerl schottengasse
# 653  2023-01-27         5739                 joseph brot
# ...
# 271  car/bike/metro         1
# 272          travel         1
# 273     merchandise         1
# 274       groceries         1
# 275       groceries         1
# 276       groceries         1
# 277       groceries         1
# 278       groceries         1
# 279       groceries         1
# 281       groceries         1
# 282          dining         1
# 283          dining         1
# 284          dining         1
# 285          dining         2
# 286          dining         1
# 287          dining         1
# 288          dining         1
# 289       groceries         1
# 290       groceries         1
# 291          dining         1
# 292       groceries         1
# 293       groceries         1
# 294     health care         1
# 295       groceries         1
# 296          dining         1
# 297          dining         1
# 298     merchandise         1
# 299     merchandise         1
# 300          dining         1
# 301          dining         1
# 302  car/bike/metro         1
# 303       groceries         1
# 304       groceries         1
# 305          dining         1
# 306       groceries         1
# 307            home         1
# 308          dining         1
# 309       groceries         1
# 310          dining         1
# 311       groceries         1
# 312       groceries         1
# 313       groceries         1
# 314       groceries         1
# 315   entertainment         1
# 317       groceries         1
# 318        learning         1
# 319     merchandise         1
# 320  car/bike/metro         1
# 321          dining         1
# 322     merchandise         1
# 323          dining         1
# 324       groceries         1
# 325       groceries         1
# 326          dining         1
# 327        learning         1
# 328          dining         1
# 329          dining         1
# 330          dining         1
# 331        learning         1
# 332          dining         1
# 333          dining         1
# 334       groceries         1
# 336        exercise         1
# 337          dining         1
# 338       groceries         1
# 339        learning         1
# 340          dining         1
# 341          dining         1
# 342       groceries         1
# 344       groceries         1
# 345       groceries         1
# 346       groceries         1
# 348          dining         1
# 349     health care         1
# 350       groceries         1
# 351       groceries         1
# 352  car/bike/metro         1
# 353        learning         1
# 354          dining         1
# 355        learning         1
# 356          dining         1
# 357       groceries         1
# 358       groceries         1
# 359       groceries         1
# 360       groceries         1
# 361     health care         1
# 362       groceries         1
# 363       groceries         1
# 364       groceries         1
# 365     merchandise         1
# 366          dining         1
# 368       groceries         1
# 369            home         1
# 370       groceries         1
# 371       groceries         1
# 372       groceries         1
# 374          dining         1
# 375       groceries         1
# 376          dining         1
# 377       groceries         1
# 378       groceries         1
# 380        exercise         1
# 381       groceries         1
# 382            home         1
# 383     merchandise         1
# 384       groceries         1
# 385          dining         1
# 386  car/bike/metro         1
# 387     merchandise         1
# 388       groceries         1
# 389       groceries         1
# 391       groceries         1
# 392     health care         1
# 393            home         1
# 394          dining         1
# 395       groceries         1
# 396     health care         1
# 397          dining         1
# 398   entertainment         1
# 399  car/bike/metro         1
# 400  car/bike/metro         1
# 401       groceries         1
# 402  car/bike/metro         1
# 403          dining         1
# 404       groceries         1
# 405       groceries         1
# 406            home         1
# 407          travel         1
# 408       groceries         1
# 410          dining         1
# 411          dining         1
# 412          dining         1
# 413       groceries         1
# 414   entertainment         1
# 415       groceries         1
# 416          dining         1
# 417       groceries         1
# 418  car/bike/metro         1
# 419  car/bike/metro         1
# 420            home         1
# 422          dining         1
# 423          dining         1
# 424       groceries         1
# 425       groceries         1
# 426            home         1
# 427     merchandise         1
# 428       groceries         1
# 429   entertainment         1
# 430  car/bike/metro         1
# 431  car/bike/metro         1
# 432       groceries         1
# 433       groceries         1
# 434       groceries         1
# 435       groceries         1
# 436          dining         1
# 437          dining         1
# 438          dining         1
# 439          dining         1
# 440          dining         1
# 441          dining         1
# 442          dining         1
# 443       groceries         1
# 444          dining         1
# 445          dining         1
# 446          dining         1
# 447          dining         1
# 448       groceries         1
# 449          dining         1
# 450          dining         1
# 451          dining         1
# 452       groceries         1
# 453       groceries         1
# 454  car/bike/metro         1
# 455          dining         1
# 457     merchandise         1
# 458       groceries         1
# 459       groceries         1
# 460       groceries         1
# 462       groceries         1
# 463       groceries         1
# 464       groceries         1
# 465       groceries         1
# 466          dining         1
# 467          dining         1
# 468          dining         1
# 469          dining         1
# 470     merchandise         1
# 471          dining         1
# 472       groceries         1
# 473       groceries         1
# 474       groceries         1
# 475     merchandise         1
# 476       groceries         1
# 477       groceries         1
# 478          dining         1
# 479          dining         1
# 480          dining         1
# 481          dining         1
# 482          dining         1
# 483       groceries         1
# 484          dining         1
# 485       groceries         1
# 486       groceries         1
# 487       groceries         1
# 489          dining         1
# 490          dining         1
# 491       groceries         1
# 492          dining         1
# 493       groceries         1
# 494       groceries         1
# 495          dining         1
# 496       groceries         1
# 497       groceries         1
# 498       groceries         1
# 499          dining         1
# 500       groceries         1
# 501          dining         1
# 502       groceries         1
# 504          dining         1
# 508          dining         1
# 509          dining         1
# 510          dining         1
# 511       groceries         1
# 512       groceries         1
# 513          dining         1
# 514       groceries         1
# 515          dining         1
# 516          dining         1
# 517          dining         1
# 518       groceries         1
# 519          dining         1
# 520       groceries         1
# 522       groceries         1
# 523       groceries         1
# 524          dining         1
# 525       groceries         1
# 526          dining         1
# 527          dining         1
# 528          dining         1
# 529          dining         1
# 530       groceries         1
# 531       groceries         1
# 532          dining         1
# 533          dining         1
# 534          dining         1
# 535       groceries         1
# 537       groceries         1
# 538       groceries         1
# 539          dining         1
# 540          dining         1
# 541       groceries         1
# 542       groceries         1
# 543       groceries         1
# 544          dining         1
# 545       groceries         1
# 547        exercise         1
# 548       groceries         1
# 549       groceries         1
# 550       groceries         1
# 551          dining         1
# 552     health care         1
# 553       groceries         1
# 554          dining         1
# 555       groceries         1
# 556       groceries         1
# 557          dining         1
# 558          dining         1
# 559          dining         1
# 560          dining         1
# 561          dining         1
# 562       groceries         1
# 563       groceries         1
# 564          dining         1
# 565       groceries         1
# 566          dining         1
# 567       groceries         1
# 568          dining         1
# 569          dining         1
# 570       groceries         1
# 571       groceries         1
# 572          dining         1
# 573       groceries         1
# 574       groceries         1
# 577       groceries         1
# 578          dining         1
# 579          dining         1
# 580          dining         1
# 581          dining         1
# 582       groceries         1
# 583          dining         1
# 584          dining         1
# 585          dining         1
# 586          dining         1
# 587       groceries         1
# 588          dining         1
# 589       groceries         1
# 590       groceries         1
# 592       groceries         1
# 593          dining         1
# 594          dining         1
# 595       groceries         1
# 596       groceries         1
# 597          dining         1
# 598       groceries         1
# 599          dining         1
# 600       groceries         1
# 601       groceries         1
# 602       groceries         1
# 603          dining         1
# 604          dining         1
# 605          dining         1
# 606       groceries         1
# 607     merchandise         1
# 608          dining         1
# 609            home         1
# 610       groceries         1
# 611          dining         1
# 612     merchandise         1
# 613          dining         1
# 614     merchandise         1
# 615     merchandise         1
# 616          dining         1
# 618  car/bike/metro         1
# 619          dining         1
# 620     merchandise         1
# 621          dining         1
# 622          dining         1
# 623  car/bike/metro         1
# 624  car/bike/metro         1
# 625     merchandise         1
# 626     merchandise         1
# 627          dining         1
# 628          dining         1
# 629          dining         1
# 630     merchandise         1
# 631          dining         1
# 632          dining         1
# 633     merchandise         1
# 634        exercise         1
# 635          dining         1
# 636          dining         1
# 637          dining         1
# 638       groceries         1
# 639          dining         1
# 640  car/bike/metro         1
# 641       groceries         1
# 642       groceries         1
# 643          dining         1
# 644          dining         1
# 646          dining         1
# 647          dining         1
# 648          dining         1
# 649          dining         1
# 650       groceries         1
# 651          dining         1
# 652          dining         1
# 653          dining         1
# 654       groceries         1
# 655   entertainment         1
# 656          dining         1
# 657          dining         1
# 658          dining         1
# 660       groceries         1
# 661          dining         1
# 662       groceries         1
# 663       groceries         1
# 664          dining         1
# 665       groceries         1
# 667        exercise         1
# 668          dining         1
# 669       groceries         1
# 670          dining         1
# 671          dining         1
# 672          dining         1
# 673          dining         1
# 674       groceries         1
# 675       groceries         1
# 676          dining         1
# 677       groceries         1
# 678       groceries         1
# 679       groceries         1
# 680       groceries         1
# 681          dining         1
# 682          dining         1
# 683       groceries         1
# 684  car/bike/metro         1
# 685          dining         1
# 686       groceries         1
# 687       groceries         1
# 688          dining         1
# 689       groceries         1
# 690       groceries         1
# 691       groceries         1
# 693          dining         1
# 694          dining         1
# 0         groceries         1
# 1         groceries         1
# 2            dining         1
# 3         groceries         1
# 4         utilities         1
# 6         groceries         1
# 7         groceries         1
# 8         groceries         1
# 9              home         1
# 10              NaN         1
# 11              NaN         1
# 12           dining         1
# 13           dining         1
# 14        groceries         1
# 15           dining         1
# 16           travel         1
# 17           dining         1
# 18           dining         1
# 19              NaN         1
# 20              NaN         1
# 21              NaN         1
# 22              NaN         1
# 23              NaN         1
# 24              NaN         1
# 25        groceries         1
# 26   car/bike/metro         1
# 27           travel         1
# 28           travel         1
# 29           travel         1
# 30             home         1
# 31             home         1
# 32        groceries         1
# 33   car/bike/metro         1
# 36      merchandise         1
# 37   car/bike/metro         1
# 38           dining         1
# 39              NaN         1
# 40           dining         1
# 41              NaN         1
# 42        groceries         1
# 43              NaN         1
# 44        groceries         1
# 45        groceries         1
# 46        groceries         1
# 47              NaN         1
# 48           dining         1
# 49        groceries         1
# 50              NaN         1
# 51              NaN         1
# 52        groceries         1
# 53        groceries         1
# 54        groceries         1
# 56              NaN         1
# 57           dining         1
# 58              NaN         1
# 59              NaN         1
# 60              NaN         1
# 61           dining         1
# 62              NaN         1
# 63           dining         1
# 0    car/bike/metro         1
# 1    car/bike/metro         1
# 3    car/bike/metro         1
# 4         utilities         1
# 6       merchandise         1
# Chat GPT labeled kaffeekuche as dining
# Chat GPT labeled das kolin as dining
# Chat GPT labeled sumup  *cafe comet as dining
# Chat GPT labeled sumup  *cafe comet as dining
# Chat GPT labeled cafe savoy as dining
# Chat GPT labeled hbla für gartenbau und as home
# Chat GPT labeled cafe konditorei heiner as dining
#
# CHATGPT could not categorize the business correctly: uzr*bergzeit.at
# Original category: merchandise
# Amount: $89.95
# Chat GPT labeled secret garden as home
# Chat GPT labeled tjx oesterreich ltd. as merchandise
# Chat GPT labeled webshop burgtheater as entertainment
# Chat GPT labeled florida driving recor as car/bike/metro
# Chat GPT labeled st martin kg as groceries
# Chat GPT labeled apapika bowls as dining
# Chat GPT labeled der kunstverein in bre as entertainment
#
# CHATGPT could not categorize the business correctly: alex bremen (1040)
# Original category: dining
# Amount: $12.2
#
# CHATGPT could not categorize the business correctly: paypal *vbn
# Original category: internet
# Amount: $30.08
#
# CHATGPT could not categorize the business correctly: paypal *vbn
# Original category: internet
# Amount: $37.88
#
# CHATGPT could not categorize the business correctly: emma am see
# Original category: dining
# Amount: $10.42
# Dataframe contains no unapproved categories. Import successful!
